# %%
import os
import sys

sys.path.append(os.path.abspath("../"))
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import training.classifier_architectures as u_classifiers
import training.encoder_architectures as u_encoders

# %% [markdown]
# ##### Python Notebook: Architectures
#
# The purpose of this notebook is to visualize and analyze the available model architectures that can be used in the training of the encoder and classifier.

# %% [markdown]
# # Encoder Architectures

# %%
input_dims = (480, 320)

# %% [markdown]
# ### Encoder Ires Single Category

# %%
categories = ["penaltyMark"]
model = u_encoders.get_encoder(
    "inverted_residual_single_category",
    *input_dims,
    categories,
    n_context=0,
    use_batch_norm=False,
)
model.summary()

# %% [markdown]
# ### Encoder Ires Single Category v2

# %%
categories = ["penaltyMark", "ball"]
model = u_encoders.get_encoder(
    "inverted_residual_single_category_v2",
    *input_dims,
    categories,
    n_context=0,
    use_batch_norm=False,
)
model.summary()

# %% [markdown]
# # Classifier Architectures

# %% [markdown]
# ### Classifier Ires Single Category

# %%
model = u_classifiers.get_classifier(
    "classifier_inverted_residual_single_category_v2",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()

# %% [markdown]
# ### Classifier Ires Single Category v2

# %%
model = u_classifiers.get_classifier(
    "classifier_inverted_residual_single_category_v2",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()

# %% [markdown]
# ### Classifier Single Category

# %%
model = u_classifiers.get_classifier(
    "classifier_single_category",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()

# %%
model = u_classifiers.get_classifier(
    "classifier_single_category_v2",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()

# %%
model = u_classifiers.get_classifier(
    "classifier_ires_single_category",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()

# %%
model = u_classifiers.get_classifier(
    "classifier_ires_single_category_v2",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()

# %%
model = u_classifiers.get_classifier(
    "classifier_ires_single_category_v3",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()

# %%
model = u_classifiers.get_classifier(
    "classifier_ires_single_category_v4",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()

# %%
model = u_classifiers.get_classifier(
    "classifier_ires_single_category_v5",
    (32, 32),
    channels_in=3,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
    use_batch_norm=False,
)
model.summary()
