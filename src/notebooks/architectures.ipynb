# %%
import os
import sys

sys.path.append(os.path.abspath("../"))
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

from train.models import FullModel

# %% [markdown]
# ##### Python Notebook: Architectures
# The purpose of this notebook is to visualize and analyze the available model architectures that can be used in the training of the encoder and classifier.

# %% [markdown]
# #### Encoder Architectures

# %%
input_dims = (480, 320)

# %% [markdown]
# # Default Light

# %%
model = FullModel("default_light", *input_dims)
model.encoder.summary()

# %% [markdown]
# # Default Heavy

# %%
model = FullModel("default_heavy", *input_dims)
model.encoder.summary()

# %% [markdown]
# # Inverted Residual Light

# %%
model = FullModel("inverted_residual_light", *input_dims)
model.encoder.summary()

# %% [markdown]
# # Inverted Residual Single Category

# %%
model = FullModel("inverted_residual_single_category", *input_dims)
model.encoder.summary()

# %% [markdown]
# # Inverted Residual Single Category v2

# %%
model = FullModel("inverted_residual_single_category_v2", *input_dims)
model.encoder.summary()
