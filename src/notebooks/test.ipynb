# %%
import os
import sys

sys.path.append(os.path.abspath("../"))

import matplotlib.pyplot as plt

from util import dataset_io as u_dataset_io
from util import image as u_image

# %%
string = "GORE23_Gott_Gott_CompetitionWalk_Default__HTWK-Robots_1stHalf_1_Upper66793"

file = "_".join(string.split("_")[0:-1])
image = string.split("_")[-1]

image = u_dataset_io.load_image_direct(
    f"../../data/groundtruth_raw/{file}/{image}.jpg", image_format=u_image.ImageFormat.RGB
)

plt.imshow(image)

plt.imsave(f"{string}.jpg", image)
