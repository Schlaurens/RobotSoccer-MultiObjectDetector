# %%
import os
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

sys.path.append(os.path.abspath("../"))
from util import dataset as u_dataset

# %%
def read_csv_file(file_path):
    """
    Reads a CSV file from the given path and returns a pandas DataFrame.

    Parameters:
    file_path (str): Path to the CSV file.

    Returns:
    pd.DataFrame: DataFrame containing the CSV data.
    """
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"Error: The file at {file_path} was not found.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None


run_1 = read_csv_file("../../data/evaluation/classifier-basic/run_1.csv")
run_2 = read_csv_file("../../data/evaluation/classifier-basic/run_2.csv")
run_3 = read_csv_file("../../data/evaluation/classifier-basic/run_3.csv")

log_path = Path("../../logs/fit/")

# %%
architectures = ["conv_v1", "conv_v2", "conv_v3", "conv_v4"]
runs = [run_1, run_2, run_3]

cla_runs = {}

for i, arch in enumerate(architectures):
    for j, run in enumerate(runs):
        cla_runs[f"cla{i + 1}_run{j + 1}"] = run[run["architecture"] == arch]

# %%
# ── Data ──────────────────────────────────────────────────────────────────────
architectures = architectures = [
    r"$\mathrm{Cla}_1$",
    r"$\mathrm{Cla}_2$",
    r"$\mathrm{Cla}_3$",
    r"$\mathrm{Cla}_4$",
]

classes = ["Ball", "Elfmeterpunkt", "Linienkreuzung"]

# %%
ceilings = {
    "Ball": float(cla_runs["cla1_run1"]["encoder_recall_at_k_ball"].iloc[0]),
    "Elfmeterpunkt": float(cla_runs["cla1_run1"]["encoder_recall_at_k_penaltyMark"].iloc[0]),
    "Linienkreuzung": float(cla_runs["cla1_run1"]["encoder_recall_at_k_intersections"].iloc[0]),
}

# %%
ap_values = {
    "Ball": [
        [
            float(cla_runs["cla1_run1"]["ball_ap_pooled"].iloc[0]),
            float(cla_runs["cla1_run2"]["ball_ap_pooled"].iloc[0]),
            float(cla_runs["cla1_run3"]["ball_ap_pooled"].iloc[0]),
        ],
        [
            float(cla_runs["cla2_run1"]["ball_ap_pooled"].iloc[0]),
            float(cla_runs["cla2_run2"]["ball_ap_pooled"].iloc[0]),
            float(cla_runs["cla2_run3"]["ball_ap_pooled"].iloc[0]),
        ],
        [
            float(cla_runs["cla3_run1"]["ball_ap_pooled"].iloc[0]),
            float(cla_runs["cla3_run2"]["ball_ap_pooled"].iloc[0]),
            float(cla_runs["cla3_run3"]["ball_ap_pooled"].iloc[0]),
        ],
        [
            float(cla_runs["cla4_run1"]["ball_ap_pooled"].iloc[0]),
            float(cla_runs["cla4_run2"]["ball_ap_pooled"].iloc[0]),
            float(cla_runs["cla4_run3"]["ball_ap_pooled"].iloc[0]),
        ],
    ],
    "Elfmeterpunkt": [
        [
            float(cla_runs["cla1_run1"]["penaltyMark_ap_pooled"].iloc[0]),
            float(cla_runs["cla1_run2"]["penaltyMark_ap_pooled"].iloc[0]),
            float(cla_runs["cla1_run3"]["penaltyMark_ap_pooled"].iloc[0]),
        ],
        [
            float(cla_runs["cla2_run1"]["penaltyMark_ap_pooled"].iloc[0]),
            float(cla_runs["cla2_run2"]["penaltyMark_ap_pooled"].iloc[0]),
            float(cla_runs["cla2_run3"]["penaltyMark_ap_pooled"].iloc[0]),
        ],
        [
            float(cla_runs["cla3_run1"]["penaltyMark_ap_pooled"].iloc[0]),
            float(cla_runs["cla3_run2"]["penaltyMark_ap_pooled"].iloc[0]),
            float(cla_runs["cla3_run3"]["penaltyMark_ap_pooled"].iloc[0]),
        ],
        [
            float(cla_runs["cla4_run1"]["penaltyMark_ap_pooled"].iloc[0]),
            float(cla_runs["cla4_run2"]["penaltyMark_ap_pooled"].iloc[0]),
            float(cla_runs["cla4_run3"]["penaltyMark_ap_pooled"].iloc[0]),
        ],
    ],
    "Linienkreuzung": [
        [
            float(cla_runs["cla1_run1"]["intersections_mAP"].iloc[0]),
            float(cla_runs["cla1_run2"]["intersections_mAP"].iloc[0]),
            float(cla_runs["cla1_run3"]["intersections_mAP"].iloc[0]),
        ],
        [
            float(cla_runs["cla2_run1"]["intersections_mAP"].iloc[0]),
            float(cla_runs["cla2_run2"]["intersections_mAP"].iloc[0]),
            float(cla_runs["cla2_run3"]["intersections_mAP"].iloc[0]),
        ],
        [
            float(cla_runs["cla3_run1"]["intersections_mAP"].iloc[0]),
            float(cla_runs["cla3_run2"]["intersections_mAP"].iloc[0]),
            float(cla_runs["cla3_run3"]["intersections_mAP"].iloc[0]),
        ],
        [
            float(cla_runs["cla4_run1"]["intersections_mAP"].iloc[0]),
            float(cla_runs["cla4_run2"]["intersections_mAP"].iloc[0]),
            float(cla_runs["cla4_run3"]["intersections_mAP"].iloc[0]),
        ],
    ],
}

euc_values = {
    "Ball": [
        [
            float(cla_runs["cla1_run1"]["classifier_euc_error_ball"].iloc[0]),
            float(cla_runs["cla1_run2"]["classifier_euc_error_ball"].iloc[0]),
            float(cla_runs["cla1_run3"]["classifier_euc_error_ball"].iloc[0]),
        ],
        [
            float(cla_runs["cla2_run1"]["classifier_euc_error_ball"].iloc[0]),
            float(cla_runs["cla2_run2"]["classifier_euc_error_ball"].iloc[0]),
            float(cla_runs["cla2_run3"]["classifier_euc_error_ball"].iloc[0]),
        ],
        [
            float(cla_runs["cla3_run1"]["classifier_euc_error_ball"].iloc[0]),
            float(cla_runs["cla3_run2"]["classifier_euc_error_ball"].iloc[0]),
            float(cla_runs["cla3_run3"]["classifier_euc_error_ball"].iloc[0]),
        ],
        [
            float(cla_runs["cla4_run1"]["classifier_euc_error_ball"].iloc[0]),
            float(cla_runs["cla4_run2"]["classifier_euc_error_ball"].iloc[0]),
            float(cla_runs["cla4_run3"]["classifier_euc_error_ball"].iloc[0]),
        ],
    ],
    "Elfmeterpunkt": [
        [
            float(cla_runs["cla1_run1"]["classifier_euc_error_penaltyMark"].iloc[0]),
            float(cla_runs["cla1_run2"]["classifier_euc_error_penaltyMark"].iloc[0]),
            float(cla_runs["cla1_run3"]["classifier_euc_error_penaltyMark"].iloc[0]),
        ],
        [
            float(cla_runs["cla2_run1"]["classifier_euc_error_penaltyMark"].iloc[0]),
            float(cla_runs["cla2_run2"]["classifier_euc_error_penaltyMark"].iloc[0]),
            float(cla_runs["cla2_run3"]["classifier_euc_error_penaltyMark"].iloc[0]),
        ],
        [
            float(cla_runs["cla3_run1"]["classifier_euc_error_penaltyMark"].iloc[0]),
            float(cla_runs["cla3_run2"]["classifier_euc_error_penaltyMark"].iloc[0]),
            float(cla_runs["cla3_run3"]["classifier_euc_error_penaltyMark"].iloc[0]),
        ],
        [
            float(cla_runs["cla4_run1"]["classifier_euc_error_penaltyMark"].iloc[0]),
            float(cla_runs["cla4_run2"]["classifier_euc_error_penaltyMark"].iloc[0]),
            float(cla_runs["cla4_run3"]["classifier_euc_error_penaltyMark"].iloc[0]),
        ],
    ],
    "Linienkreuzung": [
        [
            float(cla_runs["cla1_run1"]["classifier_euc_error_intersections"].iloc[0]),
            float(cla_runs["cla1_run2"]["classifier_euc_error_intersections"].iloc[0]),
            float(cla_runs["cla1_run3"]["classifier_euc_error_intersections"].iloc[0]),
        ],
        [
            float(cla_runs["cla2_run1"]["classifier_euc_error_intersections"].iloc[0]),
            float(cla_runs["cla2_run2"]["classifier_euc_error_intersections"].iloc[0]),
            float(cla_runs["cla2_run3"]["classifier_euc_error_intersections"].iloc[0]),
        ],
        [
            float(cla_runs["cla3_run1"]["classifier_euc_error_intersections"].iloc[0]),
            float(cla_runs["cla3_run2"]["classifier_euc_error_intersections"].iloc[0]),
            float(cla_runs["cla3_run3"]["classifier_euc_error_intersections"].iloc[0]),
        ],
        [
            float(cla_runs["cla4_run1"]["classifier_euc_error_intersections"].iloc[0]),
            float(cla_runs["cla4_run2"]["classifier_euc_error_intersections"].iloc[0]),
            float(cla_runs["cla4_run3"]["classifier_euc_error_intersections"].iloc[0]),
        ],
    ],
}

# %%
def extract_ap_values():
    ap_values = {cls.name: [[] for _ in range(len(architectures))] for cls in list(u_dataset.CategoryNames)}
    ceiling_values = {cls.name: [[] for _ in range(len(architectures))] for cls in list(u_dataset.CategoryNames)}
    ceiling_values_mean = {cls.name: [[] for _ in range(len(architectures))] for cls in list(u_dataset.CategoryNames)}

    for run in runs:
        for arch_idx, arch in enumerate(architectures):
            for cls in list(u_dataset.CategoryNames):
                base_dir = Path(log_path, "classifier-basic", f"run_{run}", arch)
                folders = [f for f in base_dir.iterdir() if f.is_dir()]
                if len(folders) == 1:
                    path_to_model = folders[0]
                else:
                    raise ValueError(f"Expected exactly one folder in {base_dir}, found {len(folders)}")

                # Load AP values for the class
                # precisions = np.load(path_to_model.as_posix() + f"/precisions/intersections_{cls.name}.npy")
                recalls = np.load(path_to_model.as_posix() + f"/recalls/intersections_{cls.name}.npy")
                ceiling_values[cls.name][arch_idx].append(np.max(recalls))
                

    for cls in list(u_dataset.IntersectionType)[1:]:
        
        ceiling_values_mean[cls.name] = np.max(ceiling_values[cls.name], 1)
        print("Std:", np.std(ceiling_values[cls.name], 1)) 
        
    print(ceiling_values_mean)
    return ap_values, ceiling_values_mean

# %%
# ── Shared Layoutparameters ─────────────────────────────────────────────────
x = np.arange(len(architectures))
n_classes = len(classes)
bar_width = 0.22
offsets = np.linspace(-(n_classes - 1) / 2, (n_classes - 1) / 2, n_classes) * bar_width
colors = ["#0072B2", "#E69F00", "#009E73"]  # Okabe-Ito
mean_color = "#CC79A7"


# ── Helper: Ceilings ─────────────────────────────────────────────
def draw_ceilings(ax, ceiling_dict):
    for cls, color in zip(classes, colors, strict=True):
        ceiling = ceiling_dict[cls]
        ax.axhline(
            y=ceiling,
            color=color,
            linewidth=1.2,
            linestyle="--",
            alpha=0.8,
            zorder=2,
        )


# ── Helper: Styles of axes ───────────────────────────────────────────────
def style_ax(ax):
    ax.set_xticks(x)
    ax.set_xticklabels(architectures, fontsize=11)
    ax.set_xlabel("Architektur", fontsize=11)
    ax.yaxis.grid(True, linestyle="--", alpha=0.6, zorder=0)
    ax.set_axisbelow(True)
    ax.spines[["top", "right"]].set_visible(False)


# ── Helper: Points + Mean + Connecting Lines ──────────────────────────────
def draw_points_and_mean(ax, data_dict):
    for cls, color, offset in zip(classes, colors, offsets, strict=True):
        means = []
        for i, samples in enumerate(data_dict[cls]):
            samples = np.array(samples)
            mean = np.mean(samples)
            means.append(mean)

            # Raw datapoint: random horizontal alignment (Jitter)
            jitter = np.linspace(-0.06, 0.06, len(samples))
            ax.scatter(
                x[i] + offset + jitter,
                samples,
                color=color,
                s=30,
                zorder=5,
                alpha=0.7,
                edgecolors="white",
                linewidths=0.4,
            )
            print("Mean ", cls, mean)
            # Mean
            ax.hlines(
                mean,
                x[i] + offset - 0.09,
                x[i] + offset + 0.09,
                colors=color,
                linewidth=2.5,
                zorder=6,
            )

        # Connect the means for this class
        ax.plot(
            x + offset,
            means,
            color=color,
            linewidth=0.7,
            linestyle="-",
            zorder=4,
            alpha=0.9,
            marker="",
            markersize=4,
            markerfacecolor="white",
            markeredgecolor=color,
            markeredgewidth=1.2,
        )


# ── Helper: Legend ───────────────────────────
def add_legend(ax, with_ceiling=True):
    handles = [
        plt.Line2D([0], [0], marker="o", color="w", markerfacecolor=color, markersize=7, label=cls)
        for cls, color in zip(classes, colors, strict=True)
    ]

    if with_ceiling:
        ceiling_handles = [
            plt.Line2D(
                [0],
                [0],
                color=color,
                linewidth=1.2,
                linestyle="--",
                alpha=0.8,
                label=r"Recall$@K_c$ für " + f"{cls}",
            )
            for cls, color in zip(classes, colors, strict=True)
        ]
        handles += ceiling_handles

    ax.legend(
        handles=handles,
        loc="lower right",
        framealpha=0.9,
        fontsize=9,
        ncols=2 if with_ceiling else 1,
    )


# — Plot 1: AP / mAP ————————————————————————————————————————————————————————————
fig, ax = plt.subplots(figsize=(9, 5))
draw_points_and_mean(ax, ap_values)
ax.set_ylim(0.4, 1.05)
draw_ceilings(ax, ceilings)
style_ax(ax)
ax.set_ylabel("AP / mAP", fontsize=11)
add_legend(ax)
plt.tight_layout()
plt.savefig("../../plots/classifier-basic/average_precision.pdf")

# — Plot 2: Euclidean Error ────────────────────────────────────────────────
fig, ax = plt.subplots(figsize=(9, 5))
ymax = max(v for vals in euc_values.values() for samples in vals for v in samples) * 1.2
draw_points_and_mean(ax, euc_values)
ax.set_ylim(0, 3.5)
style_ax(ax)
ax.set_ylabel(r"$\bar{e}^\prime$ [px]", fontsize=11)
add_legend(ax, with_ceiling=False)
plt.tight_layout()
plt.savefig("../../plots/classifier-basic/euclidean_error.pdf")

plt.tight_layout()
plt.show()

# %%
print(ceilings)
