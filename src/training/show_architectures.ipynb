# %%
import os
import sys

sys.path.append(os.path.abspath("../"))
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import classifier_architectures as u_classifiers
import cpn_architectures as u_cpns

# %% [markdown]
# ##### Python Notebook: Architectures
#
# The purpose of this notebook is to visualize and analyze the available model architectures that can be used in the training of the cpn and classifier.

# %% [markdown]
# # CPN Architectures

# %%
categories = ["penaltyMark", "intersections", "ball"]

input_dims = (448, 272)
channels_in = 4
colorspace = "yuyv"

# input_dims = (488, 544)
# channels_in = 1
# colorspace = "gray"

# %%
# categories = ["penaltyMark", "intersections", "ball"]
# model = u_cpns.get_cpn(
#     "ires_16x16_v1",
#     *input_dims,
#     categories,
#     n_context=0,
#     channels_in=channels_in,
#     colorspace=colorspace,
# )
# model.summary()

# %%
model = u_cpns.get_cpn(
    "conv_16x16_v1",
    *input_dims,
    categories,
    n_context=0,
    channels_in=channels_in,
    colorspace=colorspace,
)
model.summary()

# %% [markdown]
# # Classifier Architectures

# %%
model = u_classifiers.get_classifier(
    "conv_v0",
    (32, 32),
    channels_in=1,
    n_meta=0,
    n_context=0,
    n_classes=len(categories),
    with_offset=True,
)
model.summary()
